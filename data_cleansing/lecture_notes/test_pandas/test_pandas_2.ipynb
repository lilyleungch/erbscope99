# %% [markdown]
# # Pandas lecture 2

# %%
dd1 = { 'name': ['John', 'Mary', 'Peter', 'Candy', 'Dorothy', 'Emily'],
       'score': [20,30, 50, 10 , 100, 70]}

import pandas as pd

#load data into a DataFrame object:
df = pd.DataFrame(dd1)
df
# Out:
#       name  score
# 0     John     20
# 1     Mary     30
# 2    Peter     50
# 3    Candy     10
# 4  Dorothy    100
# 5    Emily     70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   score   6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#             score
# count    6.000000
# mean    46.666667
# std     33.862467
# min     10.000000
# 25%     22.500000
# 50%     40.000000
# 75%     65.000000
# max    100.000000

# %%
df.shape
# Out:
# (6, 2)

# %%
df.head(5)
# Out:
#       name  score
# 0     John     20
# 1     Mary     30
# 2    Peter     50
# 3    Candy     10
# 4  Dorothy    100

# %%
df.tail(5)
# Out:
#       name  score
# 1     Mary     30
# 2    Peter     50
# 3    Candy     10
# 4  Dorothy    100
# 5    Emily     70

# %%
df.rename(columns={'score':'score'}, inplace = True)
df2=df.rename(columns={'score':'score'})

# %%
df.iloc[2]
# Out:
# name     Peter
# score       50
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# name     Peter
# score       50
# Name: 2, dtype: object

# %%
df.loc[2,'name']
# Out:
# 'Peter'

# %%
df.loc[2:5]
# Out:
#       name  score
# 2    Peter     50
# 3    Candy     10
# 4  Dorothy    100
# 5    Emily     70

# %%
df.loc[2:5, 'score']
# Out:
# 2     50
# 3     10
# 4    100
# 5     70
# Name: score, dtype: int64

# %%
df.loc[[1,3],'score']
# Out:
# 1    30
# 3    10
# Name: score, dtype: int64

# %% [markdown]
# # to revert the column position

# %%
df[['score','name']]
# Out:
#    score     name
# 0     20     John
# 1     30     Mary
# 2     50    Peter
# 3     10    Candy
# 4    100  Dorothy
# 5     70    Emily

# %% [markdown]
# # no iloc or loc is to select column
# # iloc is to select the position
# # loc is to select the index
# # only loc can use ,
# # if no number index can use word index

# %%
df2 = df.copy()
df2.index = ['s0','s1','s2','s3','s4','s5']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, s0 to s5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   score   6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 144.0+ bytes

# %%
df2.iloc[[2,5]]
# Out:
#      name  score
# s2  Peter     50
# s5  Emily     70

# %%
df2.loc['s2']
# Out:
# name     Peter
# score       50
# Name: s2, dtype: object

# %%
df2.loc['s3','name']
# Out:
# 'Candy'

# %%
df2.loc['s1':'s4', ['score','name']]
# Out:
#     score     name
# s1     30     Mary
# s2     50    Peter
# s3     10    Candy
# s4    100  Dorothy

# %%
df2.loc['s1':'s4', 'score':'name':-1]
# Out:
#     score     name
# s1     30     Mary
# s2     50    Peter
# s3     10    Candy
# s4    100  Dorothy

# %%
s1 = pd.Series(['This', 'is', 'a', 'test', 'of', 'series'])

# %%
s1=='This'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
s1[s1=='This']
# Out:
# 0    This
# dtype: object

# %%
s1.str.contains('is')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
s1.str.contains('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
s1[s1.str.contains('e')]
# Out:
# 3      test
# 5    series
# dtype: object

# %%
s1[s1.str.contains('t',case=False)]
# Out:
# 0    This
# 3    test
# dtype: object

# %%
df2[df2['score']>30]
# Out:
#        name  score
# s2    Peter     50
# s4  Dorothy    100
# s5    Emily     70

# %%
df2[(df2['score']<20) | (df2['score']>50)]
# Out:
#        name  score
# s3    Candy     10
# s4  Dorothy    100
# s5    Emily     70

# %%
df2[df2['name'].str.contains('y',case=False)]
# Out:
#        name  score
# s1     Mary     30
# s3    Candy     10
# s4  Dorothy    100
# s5    Emily     70

# %%
df2[(df2['name'].str.contains('a',case=False)) & (df2['score']<50)]
# Out:
#      name  score
# s1   Mary     30
# s3  Candy     10

# %%
df2[df2['score']==100]['name'].item()
df2[df2['score']==100]['name'].values[0]
df2[df2['score']==100]['name'][0]
df2[df2['score']==100]['name'].iloc[0]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16268\433384614.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df2[df2['score']==100]['name'][0]
# 'Dorothy'

# %%
df2[df2['score']==df2['score'].max()]['name'].item()
df2[df2.score == df2.score.max()].name.item()
# Out:
# 'Dorothy'

# %%
df2[df2['score']==df2['score'].min()]['name'].item()
df2[df2['score']==df2['score'].min()].index.item()
# Out:
# 's3'

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calories  3 non-null      int64
#  1   duration  3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
df.describe()
# Out:
#          calories  duration
# count    3.000000       3.0
# mean   396.666667      45.0
# std     20.816660       5.0
# min    380.000000      40.0
# 25%    385.000000      42.5
# 50%    390.000000      45.0
# 75%    405.000000      47.5
# max    420.000000      50.0

# %%
df.shape
# Out:
# (3, 2)

# %%
df.head(3)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.tail(3)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.index = ['day1','day2','day3']
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
sum(df.duration)
# Out:
# 135

# %%
df.calories.loc['day1']
# Out:
# np.int64(420)

# %%
df.calories.at['day1']
# Out:
# np.int64(420)

# %%
df.calories.iloc[0]
# Out:
# np.int64(420)

# %%
df.calories.iat[0]
# Out:
# np.int64(420)

# %%
df.loc[['day3','day1'],['duration','calories']]
# Out:
#       duration  calories
# day3        45       390
# day1        50       420

# %%
df= pd.read_csv('data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df= pd.read_csv('data2.csv')
print(df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.Calories.isnull().sum() #check no of nulls
# Out:
# np.int64(2)

# %%
df.Date.isnull().sum()
# Out:
# np.int64(1)

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.fillna(value={'Calories':100})
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format = 'mixed')
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.loc[7, 'Duration'] = 45

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.dropna(subset=['Date'], inplace = True)

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.dropna(subset=['Calories'], inplace = True)

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  28 non-null     int64
#  1   Date      28 non-null     datetime64[ns]
#  2   Pulse     28 non-null     int64
#  3   Maxpulse  28 non-null     int64
#  4   Calories  28 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.3 KB

# %%
import tensorflow as tf
tf.add(1, 2).numpy()

hello = tf.constant('Hello, TensorFlow!')
hello.numpy()
b'Hello, TensorFlow!'
# Out:
# b'Hello, TensorFlow!'

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.17.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])
# Out:
# c:\Users\User\test_pandas\.venv\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
df= pd.read_csv('data_cleaned.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.dropna(subset=['Calories'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.160661  0.005679  0.922717
# Pulse    -0.160661  1.000000  0.784631  0.025121
# Maxpulse  0.005679  0.784631  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
pd.__version__
# Out:
# '2.2.2'
