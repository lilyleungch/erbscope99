# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x= {'a':[1,2,3], 'b':[4,5,6]}
df = pd.DataFrame(x, index = [7,8,9])
df
# Out:
#    a  b
# 7  1  4
# 8  2  5
# 9  3  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 7 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0 bytes

# %%
sns.lineplot(df)
# Out:
# <Axes: >

# %%
ddd= {'male':[20,30,40], 'female':[60,70,80]}
df2=pd.DataFrame(ddd, index = [1980, 1990, 2000])
sns.lineplot(df2)
plt.xticks(df2.index)
plt.show()

# %%
#sns.lineplot(data = df, x = 'a', y= 'b')  cannot manipulate the data
sns.lineplot(x= df.a, y = df.b)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
iris = sns.load_dataset('iris') # iris is a built-in dataset of seaborn
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.lineplot(data = iris, x='sepal_length', y = 'sepal_width', errorbar = None)
plt.title('Sepal Width vs length')
plt.show()

# %%
sns.distplot(iris['petal_length'])
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16992\2579550932.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['petal_length'])

# %%
sns.displot(data = iris.petal_length)

# %%
sns.displot(data=iris,x='petal_length', color = 'r',kind='kde')

# %%
tips = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.lineplot(x = tips.index, y = tips.total_bill)
# Out:
# <Axes: xlabel='None', ylabel='total_bill'>

# %%
sns.displot(data = tips, x = 'total_bill')

# %%
sns.displot(data = tips, x = 'tip', hue ='sex')

# %%
tips['bill_per_size'] = tips['total_bill'] /tips['size']
sns.displot(data = tips, x = 'bill_per_size')

# %%
tips['bill_plus_tips']=tips['total_bill']+tips['tip']
sns.displot(data = tips, x = 'bill_plus_tips')

# %%
sns.histplot(tips)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(tips['total_bill'], bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'], binwidth=5, binrange=[0,60])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#0 to 2.5, per 0.25 plot petal_width

# %%
sns.histplot(iris, x='petal_width', binwidth=0.25, binrange=[0,2.5], kde=True, hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data = tips, x = 'tip', hue ='sex')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(data = tips, x = 'tip', hue = 'sex')
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.scatterplot(data = iris, x = 'petal_length', y = 'petal_width', hue = 'species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  bill_per_size  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2       8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3       3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3       7.003333
#
#    bill_plus_tips
# 0           18.00
# 1           12.00
# 2           24.51

# %%
sns.scatterplot(data=tips, x='total_bill', y= 'tip', size = 'size',sizes=(20,500) ,hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=iris, x='species', y ='sepal_length', hue = 'species', errorbar = None)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(data = tips, x='sex', y='tip', errorbar = None, hue = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(data=tips, y='sex',x='tip',errorbar=None, hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.countplot(data = tips, x = 'size', hue = 'sex', palette = ['red', 'blue'])
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
sns.countplot(data = iris, x = 'species', hue='species', palette = ['green', 'blue', 'violet'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.boxplot(data=iris, x = 'species', y ='petal_length', showfliers = False, hue = 'species') # 50% in the box, max and min is up and down 
#outliner is the circle
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
#average per size

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  bill_per_size  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2       8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3       3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3       7.003333
#
#    bill_plus_tips
# 0           18.00
# 1           12.00
# 2           24.51

# %%
tips['tips_per_size']=tips['tip']/tips['size']
sns.boxplot(data=tips, x = 'tips_per_size', y= 'sex', hue = 'sex')
# Out:
# <Axes: xlabel='tips_per_size', ylabel='sex'>

# %%
sns.boxplot(data=tips, x ='day', y= 'total_bill', hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.scatterplot(data = iris, hue = 'species', x = 'sepal_length' , y = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.boxplot(data = iris, hue = 'species', x= 'species', y = 'petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data = iris, hue = 'species', x= 'species', y = 'petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.boxplot(data = iris, hue = 'species', x= 'species', y = 'sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(data = iris, hue = 'species', x= 'species', y = 'sepal_width')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.scatterplot(data = iris, hue = 'species', x = 'petal_length' , y = 'petal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.violinplot(data = iris, x = 'species', y= 'petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.violinplot(data = tips, x='tip', y= 'time', inner ='quart', hue = 'sex', split = True, gap = 0.1)
# Out:
# <Axes: xlabel='tip', ylabel='time'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  bill_per_size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2       8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3       3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3       7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2      11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4       6.147500
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2      13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2      11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2       8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2       9.390000
#
#      bill_plus_tips  tips_per_size
# 0             18.00       0.505000
# ...

# %%
sns.violinplot(data = tips, x = 'total_bill', hue = 'time', y='smoker', split = True, inner = 'quart', gap = 0.1)
# Out:
# <Axes: xlabel='total_bill', ylabel='smoker'>

# %%
sns.stripplot(x = 'day', y='total_bill', data = tips, jitter = True, hue = 'smoker', dodge = True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x ='day', y='total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(data = iris, x = 'petal_length', y= 'petal_width', hue = 'species')

# %%
sns.jointplot(data = iris, x = 'petal_length', y= 'petal_width', kind = 'reg')

# %%
sns.regplot(data = iris, x = 'petal_length', y = 'petal_width', color = 'r')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.lmplot(data = iris, x = 'petal_length', y = 'petal_width', hue = 'species', ci = False)

# %%
sns.lmplot(data = tips, x = 'size', y= 'tip')

# %%
sns.lmplot(data = tips, x = 'total_bill', y='tip', hue = 'smoker', ci = None, col ='sex', row = 'time')

# %%
sns.set_style('whitegrid')

# %%
sns.lmplot(data = tips, x = 'total_bill', y='tip', hue = 'smoker', ci = None, col ='sex', row = 'time')

# %%
sns.catplot(data = tips, x = 'sex', y='tip', kind ='box', col = 'time', row = 'smoker')

# %%
sns.catplot(data = tips, x = 'sex', y='tip', kind ='violin', col = 'time', row = 'smoker')

# %%
iris.corr
# Out:
# <bound method DataFrame.corr of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.corr(numeric_only = True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(numeric_only = True), 
            vmax = 1, vmin = -1, center= 0,
            annot = True, cmap = sns.diverging_palette(240, 0, s= 50, l=0, n= 50, as_cmap=True))
# Out:
# <Axes: >

# %%
sns.heatmap(iris.corr( numeric_only = True), annot = True, cmap = 'RdBu_r', vmin = -1, vmax = 1, center = 0)
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr( numeric_only = True), annot = True, cmap = 'RdBu_r', vmin = -1, vmax = 1, center = 0)
# Out:
# <Axes: >

# %%
sns.pairplot(iris, hue = 'species', kind ='reg', diag_kind = 'hist').map_lower(sns.kdeplot)
